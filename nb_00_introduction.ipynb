# %% [markdown]
# # Imaging with Nilearn
#
# Welcome to the Imaging with Nilearn course 2026!
#
# This practical session is forked from Dr Yifan Yu's [Nilearn practical repository](https://github.com/yifan0330/Nilearn2025/) from 2025, with some minor modifications.
#
# In the `Nilearn2026` folder you will find this notebook plus 2 others. Each notebook will introduce you to a different type of statistical analysis in fMRI and show you how to analyse fMRI data using the `Nilearn` package.
#
# The first notebook will begin by talking you through the basics of the `Nibabel` and `Nilearn` packages. After this, we will cover in detail first-level analyses. The second notebook will show you how to perform a second-level analysis and give further discussion of statistic values and thresholding your images.

# %% [markdown]
# ## Table of contents:
#
#  - [**Notebook 0: Introduction**](./nb_00_introduction.ipynb)
#    - [Using the notebooks](#Using-the-Notebooks)
#    - [Nilearn Setup](#Nilearn-Setup)
#    - [Contact and Feedback](#Contact-and-Feedback)
#    - [Acknowledgements](#Acknowledgements)
#    - [The Notebooks](#The-Notebooks)
#
#
#  - [Notebook 1: FMRI Data and First-Level Analysis](./nb_01_fmri_data_and_first_level_analysis.ipynb)
#  - [Notebook 2: Second-Level Analysis](./nb_02_second_level_analysis.ipynb)

# %% [markdown]
# ## Using the Notebooks

# %% [markdown]
# If you were in the `Introduction to Python 2026` course, jupyter notebooks should already feel fairly familiar! However, if you missed the python course for whatever reason here's a brief recap!
#
# > Inside each section, you will find text blocks and code blocks. The text blocks will describe and introduce new topics and the code blocks will give interactive demonstrations of how various features work. Once you have clicked inside a code block, you can edit the code and run the block by simply pressing `shift` and `enter`. Try this in the below block!

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ## Nilearn Setup

# %% [markdown]
# To get started let's install `nibabel` and `nilearn`! Today we will mainly be focusing on `nilearn` but `nibabel` is also going to be useful for working with fMRI imaging files! Here's a brief description of each of these packages:
#
#  - `Nibabel` provides support for reading and writing to neuroimaging file formats.
#  - `Nilearn` provides tools for statistical learning on neuroimaging data.
#
#  You should have already followed the instructions in the 'Setup' document – if not, please start there! You will find this in the Nilearn folder containing all materials.
#
#  The two lines of code below are designed to install the libraries we'll need for today. If you run the next cell, you should get a series of 'Requirement already satisfied:...' messages, telling you that the libraries (plus the other ones they depend on) are already installed.

# %%
# !pip install nibabel
# !pip install nilearn
# Out:
# Requirement already satisfied: nibabel in ./venv/lib/python3.13/site-packages (5.4.2)
# Requirement already satisfied: numpy>=1.25 in ./venv/lib/python3.13/site-packages (from nibabel) (2.5.3)
# Requirement already satisfied: packaging>=20 in ./venv/lib/python3.13/site-packages (from nibabel) (26.3)
# Requirement already satisfied: nilearn in ./venv/lib/python3.13/site-packages (0.14.1)
# Requirement already satisfied: jinja2>=3.1.6 in ./venv/lib/python3.13/site-packages (from nilearn) (3.1.6)
# Requirement already satisfied: joblib>=1.2.0 in ./venv/lib/python3.13/site-packages (from nilearn) (1.6.0)
# Requirement already satisfied: nibabel>=5.2.0 in ./venv/lib/python3.13/site-packages (from nilearn) (5.4.2)
# Requirement already satisfied: numpy>=1.26.0 in ./venv/lib/python3.13/site-packages (from nilearn) (2.5.3)
# Requirement already satisfied: packaging>=26.0.0 in ./venv/lib/python3.13/site-packages (from nilearn) (26.3)
# Requirement already satisfied: pandas>=2.3.0 in ./venv/lib/python3.13/site-packages (from nilearn) (3.0.6)
# Requirement already satisfied: requests>=2.33.0 in ./venv/lib/python3.13/site-packages (from nilearn) (2.34.2)
# Requirement already satisfied: scikit-learn!=1.7.0,!=1.9.0,>=1.5.0 in ./venv/lib/python3.13/site-packages (from nilearn) (1.9.1)
# Requirement already satisfied: scipy>=1.11.1 in ./venv/lib/python3.13/site-packages (from nilearn) (1.18.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.13/site-packages (from jinja2>=3.1.6->nilearn) (3.0.3)
# Requirement already satisfied: cloudpickle>=3.0 in ./venv/lib/python3.13/site-packages (from joblib>=1.2.0->nilearn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.13/site-packages (from pandas>=2.3.0->nilearn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2.3.0->nilearn) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.13/site-packages (from requests>=2.33.0->nilearn) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.13/site-packages (from requests>=2.33.0->nilearn) (3.20)
# Requirement already satisfied: urllib3<3,>=1.26 in ./venv/lib/python3.13/site-packages (from requests>=2.33.0->nilearn) (2.8.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./venv/lib/python3.13/site-packages (from requests>=2.33.0->nilearn) (2026.7.22)
# Requirement already satisfied: narwhals>=2.0.1 in ./venv/lib/python3.13/site-packages (from scikit-learn!=1.7.0,!=1.9.0,>=1.5.0->nilearn) (2.26.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in ./venv/lib/python3.13/site-packages (from scikit-learn!=1.7.0,!=1.9.0,>=1.5.0->nilearn) (3.7.0)

# %% [markdown]
# ## Contact and Feedback

# %% [markdown]
# If anyone has any further questions on or requests regarding the course please ask one of the tutors present or feel free to email me at `samuel.beaton@psych.ox.ac.uk`.
#
# If you would like to leave feedback on the course please let us know your thoughts on this [google form here](https://forms.gle/aC743VC1fWwWFG2m9)! (The form is anonymous so please speak freely!)

# %% [markdown]
# ## Acknowledgements

# %% [markdown]
# This code provided in this notebook borrows very heavily from the worked examples in the official [nilearn documentation](https://nilearn.github.io/stable/auto_examples/00_tutorials). The text of these notebooks is course-specific, however, and any questions regarding the text should be directed to the tutors.

# %% [markdown]
# ## The Notebooks
#
# You can open the notebooks by clicking the following links:
#
#  - [Notebook 1: FMRI Data and First-Level Analysis](./nb_01_fmri_data_and_first_level_analysis.ipynb)
#
#  - [Notebook 2: Second-Level Analysis](./nb_02_second_level_analysis.ipynb)
